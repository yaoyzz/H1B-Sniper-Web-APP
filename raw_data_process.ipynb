# %%
import pandas as pd
import h5py
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### JOIN 2023 data

# %%
import pandas as pd
import os

# Set the directory path where the files are located
directory_path = './Raw data/'

# Find all the xlsx files in the directory with "LCA_Disclosure_Data_FY" in their filenames
files = [f for f in os.listdir(directory_path) if f.endswith('.xlsx') and 'LCA_Disclosure_Data_FY' in f]

# Initialize an empty list to store the dataframes
dfs = []

# Loop through each file, import the data, and append it to the list of dataframes
for file in files:
    file_path = os.path.join(directory_path, file)
    df = pd.read_excel(file_path, engine='openpyxl')
    dfs.append(df)

# Concatenate the dataframes by row
combined_df = pd.concat(dfs, axis=0, ignore_index=True)

# %%
combined_df.head()
# Out:
#           CASE_NUMBER CASE_STATUS RECEIVED_DATE DECISION_DATE  \
# 0  I-200-19268-393467   Certified    2019-09-25    2019-10-01
# 1  I-200-19268-638983   Certified    2019-09-25    2019-10-01
# 2  I-200-19268-177184   Certified    2019-09-25    2019-10-01
# 3  I-200-19268-936403   Certified    2019-09-25    2019-10-01
# 4  I-200-19268-394079   Certified    2019-09-25    2019-10-01
#
#   ORIGINAL_CERT_DATE VISA_CLASS                               JOB_TITLE  \
# 0                NaT       H-1B  APPLICATION ENGINEER, OMS [15-1199.02]
# 1                NaT       H-1B                         BI DEVELOPER II
# 2                NaT       H-1B                        QUALITY ENGINEER
# 3                NaT       H-1B        SOFTWARE DEVELOPER, APPLICATIONS
# 4                NaT       H-1B               QUALITY ENGINEER LEVEL II
#
#   SOC_CODE                          SOC_TITLE FULL_TIME_POSITION BEGIN_DATE  \
# 0  15-1199    COMPUTER OCCUPATIONS, ALL OTHER                  Y 2019-10-07
# 1  15-1132  SOFTWARE DEVELOPERS, APPLICATIONS                  Y 2020-01-08
# 2  17-2141               MECHANICAL ENGINEERS                  Y 2019-10-03
# 3  15-1132  SOFTWARE DEVELOPERS, APPLICATIONS                  Y 2019-10-07
# 4  15-1199    COMPUTER OCCUPATIONS, ALL OTHER                  Y 2019-10-09
#
#     END_DATE  TOTAL_WORKER_POSITIONS  NEW_EMPLOYMENT  CONTINUED_EMPLOYMENT  \
# 0 2022-10-07                       1               1                     0
# 1 2023-01-07                       1               0                     1
# 2 2022-10-02                       1               0                     0
# 3 2022-10-01                       1               0                     1
# 4 2022-10-08                       1               0                     0
#
#    CHANGE_PREVIOUS_EMPLOYMENT  NEW_CONCURRENT_EMPLOYMENT  CHANGE_EMPLOYER  \
# 0                           0                          0                0
# 1                           0                          0                0
# 2                           0                          0                1
# 3                           0                          0                0
# 4                           1                          0                0
#
#    AMENDED_PETITION                   EMPLOYER_NAME  \
# 0                 0             JO-ANN STORES, INC.
# 1                 0           DENKEN SOLUTIONS INC.
# 2                 0                    EPITEC, INC.
# 3                 0  SYSTEMS TECHNOLOGY GROUP, INC.
# 4                 0       E-GIANTS TECHNOLOGIES LLC
#
#                    TRADE_NAME_DBA                   EMPLOYER_ADDRESS1  \
# 0  JO-ANN FABRIC AND CRAFT STORES                    5555 DARROW ROAD
# 1                             NaN            9170 IRVINE CENTER DRIVE
# 2                             NaN                   24800 DENSO DRIVE
# 3                             NaN  3001 W. BIG BEAVER ROAD, SUITE 500
# 4                             NaN                8033 UNIVERSITY BLVD
#
#   EMPLOYER_ADDRESS2 EMPLOYER_CITY EMPLOYER_STATE EMPLOYER_POSTAL_CODE  \
# 0               NaN        HUDSON             OH                44236
# 1       SUITE # 200        IRVINE             CA                92618
# 2          STE. 150    SOUTHFIELD             MI                48033
# 3               NaN          TROY             MI                48084
# 4           SUITE A         CLIVE             IA                50325
#
#            EMPLOYER_COUNTRY EMPLOYER_PROVINCE EMPLOYER_PHONE  \
# 0  UNITED STATES OF AMERICA               NaN     3304636787
# 1  UNITED STATES OF AMERICA               NaN     8017923416
# 2  UNITED STATES OF AMERICA               NaN     2483536800
# 3  UNITED STATES OF AMERICA               NaN     2486439010
# 4  UNITED STATES OF AMERICA               NaN     5153091451
#
#    EMPLOYER_PHONE_EXT  NAICS_CODE EMPLOYER_POC_LAST_NAME  \
# 0                 NaN      451120                 KLUSKA
# 1                 NaN      541512                MADDULA
# 2                 NaN      541511                WILDMAN
# 3                 NaN      541511                  ARVAL
# 4                 NaN      541511              BODDULURI
#
#   EMPLOYER_POC_FIRST_NAME EMPLOYER_POC_MIDDLE_NAME  \
# 0                  KRYSTA                      NaN
# 1                     RAJ                      NaN
# 2                  TAYLOR                      NaN
# 3                 SREESHA                      NaN
# 4                 KRISHNA                      NaN
#
#         EMPLOYER_POC_JOB_TITLE               EMPLOYER_POC_ADDRESS1  \
# 0  MANAGER, TALENT ACQUISITION                    5555 DARROW ROAD
# 1           SOLUTION ARCHITECT            9170 IRVINE CENTER DRIVE
# 2             IMMIGRATION LEAD                   24800 DENSO DRIVE
# 3        IMMIGRATION PARALEGAL  3001 W. BIG BEAVER ROAD, SUITE 500
# 4                          CEO                8033 UNIVERSITY BLVD
#
#   EMPLOYER_POC_ADDRESS2 EMPLOYER_POC_CITY EMPLOYER_POC_STATE  \
# 0                   NaN            HUDSON                 OH
# 1           SUITE # 200            IRVINE                 CA
# 2              STE. 150        SOUTHFIELD                 MI
# 3                   NaN              TROY                 MI
# 4               SUITE A             CLIVE                 IA
#
#   EMPLOYER_POC_POSTAL_CODE      EMPLOYER_POC_COUNTRY EMPLOYER_POC_PROVINCE  \
# 0                    44236  UNITED STATES OF AMERICA                   NaN
# 1                    92618  UNITED STATES OF AMERICA                   NaN
# 2                    48033  UNITED STATES OF AMERICA                   NaN
# 3                    48084  UNITED STATES OF AMERICA                   NaN
# 4                    50325  UNITED STATES OF AMERICA                   NaN
#
#   EMPLOYER_POC_PHONE  EMPLOYER_POC_PHONE_EXT               EMPLOYER_POC_EMAIL  \
# 0         3304636787                     NaN          KRYSTA.KLUSKA@JOANN.COM
# 1         8017923416                     NaN  IMMIGRATION@DENKENSOLUTIONS.COM
# 2         2483536800                     NaN           IMMIGRATION@EPITEC.COM
# 3         2486439010                     NaN          SREESHA.ARVAL@STGIT.COM
# 4         5153091451                     NaN             LEGAL@THEEGIANTS.COM
#
#   AGENT_REPRESENTING_EMPLOYER AGENT_ATTORNEY_LAST_NAME  \
# 0                           Y                  TZU-KAI
# 1                           Y                   YELENA
# 2                           Y                  NATALIA
# 3                           N                      NaN
# 4                           N                      NaN
#
#   AGENT_ATTORNEY_FIRST_NAME AGENT_ATTORNEY_MIDDLE_NAME  \
# 0                   TZU-KAI                        NaN
# 1                    YELENA                        NaN
# 2                   NATALIA                     MADLEN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#   AGENT_ATTORNEY_ADDRESS1 AGENT_ATTORNEY_ADDRESS2 AGENT_ATTORNEY_CITY  \
# 0   333 WEST WACKER DRIVE              15TH FLOOR             CHICAGO
# 1   6622 SOUTHPOINT DR. S                 STE 330        JACKSONVILLE
# 2  755 W. BIG BEAVER ROAD              SUITE 1100                TROY
# 3                     NaN                     NaN                 NaN
# 4                     NaN                     NaN                 NaN
#
#   AGENT_ATTORNEY_STATE AGENT_ATTORNEY_POSTAL_CODE    AGENT_ATTORNEY_COUNTRY  \
# 0                   IL                      60606  UNITED STATES OF AMERICA
# 1                   FL                      32216  UNITED STATES OF AMERICA
# 2                   MI                      48084  UNITED STATES OF AMERICA
# 3                  NaN                        NaN                       NaN
# 4                  NaN                        NaN                       NaN
#
#   AGENT_ATTORNEY_PROVINCE  AGENT_ATTORNEY_PHONE  AGENT_ATTORNEY_PHONE_EXT  \
# 0                     NaN          3.122636e+09                       NaN
# 1                     NaN          9.043890e+09                       NaN
# 2                     NaN          2.485200e+09                       NaN
# 3                     NaN                   NaN                       NaN
# 4                     NaN                   NaN                       NaN
#
#       AGENT_ATTORNEY_EMAIL_ADDRESS               LAWFIRM_NAME_BUSINESS_NAME  \
# 0                 KLO@FRAGOMEN.COM  FRAGOMEN, DEL REY, BERNSEN & LOEWY, LLP
# 1  USCISNOTICES@SCARBOROUGHLAW.COM                  SCARBOROUGH LAW, L.L.C.
# 2   NATALIA.SARRAF@ELLISPORTER.COM                        ELLIS PORTER, PLC
# 3                              NaN                                      NaN
# 4                              NaN                                      NaN
#
#   STATE_OF_HIGHEST_COURT NAME_OF_HIGHEST_STATE_COURT  WORKSITE_WORKERS  \
# 0                     IL               SUPREME COURT               NaN
# 1                     FL       FLORIDA SUPREME COURT               NaN
# 2                     MI               SUPREME COURT               NaN
# 3                    NaN                         NaN               NaN
# 4                    NaN                         NaN               NaN
#
#   SECONDARY_ENTITY SECONDARY_ENTITY_BUSINESS_NAME  \
# 0                N                            NaN
# 1                Y                     NAVIHEALTH
# 2                Y             Ford Motor Company
# 3                Y             Ford Motor Company
# 4                Y                     KROGER INC
#
#              WORKSITE_ADDRESS1      WORKSITE_ADDRESS2 WORKSITE_CITY  \
# 0             5555 Darrow Road                    NaN        Hudson
# 1         210 WESTWOOD PL #400                    NaN     BRENTWOOD
# 2  21 Town Center Office (TCO)  18900 Michigan Avenue      Dearborn
# 3          21001 Van Born Road                    NaN        Taylor
# 4           11450, GROOMS ROAD                    NaN      BLUE ASH
#
#   WORKSITE_COUNTY WORKSITE_STATE WORKSITE_POSTAL_CODE  WAGE_RATE_OF_PAY_FROM  \
# 0          Summit             OH                44224              100000.00
# 1      WILLIAMSON             TN                37027                  38.57
# 2           Wayne             MI                48126                  43.50
# 3           Wayne             MI                48180                  57.69
# 4        HAMILTON             OH                45242               75000.00
#
#    WAGE_RATE_OF_PAY_TO WAGE_UNIT_OF_PAY  PREVAILING_WAGE PW_UNIT_OF_PAY  \
# 0                  NaN             Year          95118.0           Year
# 1                38.57             Hour             39.0           Hour
# 2                  NaN             Hour             39.0           Hour
# 3                57.69             Hour             53.0           Hour
# 4                  NaN             Year          65333.0           Year
#
#   PW_TRACKING_NUMBER PW_WAGE_LEVEL PW_OES_YEAR PW_OTHER_SOURCE  PW_OTHER_YEAR  \
# 0                NaN            IV        2018             OES            NaN
# 1                NaN            II        2019             OES            NaN
# 2                NaN            II        2019             OES            NaN
# 3                NaN            IV        2019             OES            NaN
# 4                NaN            II        2019             OES            NaN
#
#   PW_SURVEY_PUBLISHER PW_SURVEY_NAME  TOTAL_WORKSITE_LOCATIONS  \
# 0                 NaN            NaN                       NaN
# 1                 NaN            NaN                       NaN
# 2                 NaN            NaN                       NaN
# 3                 NaN            NaN                       NaN
# 4                 NaN            NaN                       NaN
#
#   AGREE_TO_LC_STATEMENT H-1B_DEPENDENT WILLFUL_VIOLATOR SUPPORT_H1B  \
# 0                     Y              N                N         NaN
# 1                     Y              Y                N           Y
# 2                     Y              Y                N           Y
# 3                     Y              Y                N           Y
# 4                     Y              Y                N           Y
#
#   STATUTORY_BASIS APPENDIX_A_ATTACHED  PUBLIC_DISCLOSURE PREPARER_LAST_NAME  \
# 0             NaN                 NaN  Disclose Business                NaN
# 1            BOTH                 NaN  Disclose Business                NaN
# 2            BOTH                 NaN  Disclose Business                NaN
# 3            BOTH                 NaN  Disclose Business                NaN
# 4            BOTH                 NaN  Disclose Business                NaN
#
#   PREPARER_FIRST_NAME PREPARER_MIDDLE_INITIAL PREPARER_BUSINESS_NAME  \
# 0                 NaN                     NaN                    NaN
# 1                 NaN                     NaN                    NaN
# 2                 NaN                     NaN                    NaN
# 3                 NaN                     NaN                    NaN
# 4                 NaN                     NaN                    NaN
#
#          PREPARER_EMAIL EMPLOYER_POC_ADDRESS_1 EMPLOYER_POC_ADDRESS_2  \
# 0                   NaN                    NaN                    NaN
# 1                   NaN                    NaN                    NaN
# 2                   NaN                    NaN                    NaN
# 3                   NaN                    NaN                    NaN
# 4  LEGAL@THEEGIANTS.COM                    NaN                    NaN
#
#   H1B_DEPENDENT H_1B_DEPENDENT
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN

# %% [markdown]
# #### Check and filter Visa classes in df

# %%
list( combined_df['VISA_CLASS'].unique())
# Out:
# ['H-1B', 'E-3 Australian', 'H-1B1 Chile', 'H-1B1 Singapore']

# %%
combined_df.shape
# Out:
# (2128458, 100)

# %%
# Filter the dataframe by VISA_CLASS = 'H-1B'
combined_df = combined_df[combined_df['VISA_CLASS'] == 'H-1B']

# %%
# 2128458 - 2074099 = 54359 rows were effected
combined_df.shape
# Out:
# (2074099, 100)

# %%
# combined_df.to_csv('h1b_rocord_2020_to_2023.csv', index=False)

# %% [markdown]
# ### Create database

# %%
combined_df.columns
# Out:
# Index(['CASE_NUMBER', 'CASE_STATUS', 'RECEIVED_DATE', 'DECISION_DATE',
#        'ORIGINAL_CERT_DATE', 'VISA_CLASS', 'JOB_TITLE', 'SOC_CODE',
#        'SOC_TITLE', 'FULL_TIME_POSITION', 'BEGIN_DATE', 'END_DATE',
#        'TOTAL_WORKER_POSITIONS', 'NEW_EMPLOYMENT', 'CONTINUED_EMPLOYMENT',
#        'CHANGE_PREVIOUS_EMPLOYMENT', 'NEW_CONCURRENT_EMPLOYMENT',
#        'CHANGE_EMPLOYER', 'AMENDED_PETITION', 'EMPLOYER_NAME',
#        'TRADE_NAME_DBA', 'EMPLOYER_ADDRESS1', 'EMPLOYER_ADDRESS2',
#        'EMPLOYER_CITY', 'EMPLOYER_STATE', 'EMPLOYER_POSTAL_CODE',
#        'EMPLOYER_COUNTRY', 'EMPLOYER_PROVINCE', 'EMPLOYER_PHONE',
#        'EMPLOYER_PHONE_EXT', 'NAICS_CODE', 'EMPLOYER_POC_LAST_NAME',
#        'EMPLOYER_POC_FIRST_NAME', 'EMPLOYER_POC_MIDDLE_NAME',
#        'EMPLOYER_POC_JOB_TITLE', 'EMPLOYER_POC_ADDRESS1',
#        'EMPLOYER_POC_ADDRESS2', 'EMPLOYER_POC_CITY', 'EMPLOYER_POC_STATE',
#        'EMPLOYER_POC_POSTAL_CODE', 'EMPLOYER_POC_COUNTRY',
#        'EMPLOYER_POC_PROVINCE', 'EMPLOYER_POC_PHONE', 'EMPLOYER_POC_PHONE_EXT',
#        'EMPLOYER_POC_EMAIL', 'AGENT_REPRESENTING_EMPLOYER',
#        'AGENT_ATTORNEY_LAST_NAME', 'AGENT_ATTORNEY_FIRST_NAME',
#        'AGENT_ATTORNEY_MIDDLE_NAME', 'AGENT_ATTORNEY_ADDRESS1',
#        'AGENT_ATTORNEY_ADDRESS2', 'AGENT_ATTORNEY_CITY',
#        'AGENT_ATTORNEY_STATE', 'AGENT_ATTORNEY_POSTAL_CODE',
#        'AGENT_ATTORNEY_COUNTRY', 'AGENT_ATTORNEY_PROVINCE',
#        'AGENT_ATTORNEY_PHONE', 'AGENT_ATTORNEY_PHONE_EXT',
#        'AGENT_ATTORNEY_EMAIL_ADDRESS', 'LAWFIRM_NAME_BUSINESS_NAME',
#        'STATE_OF_HIGHEST_COURT', 'NAME_OF_HIGHEST_STATE_COURT',
#        'WORKSITE_WORKERS', 'SECONDARY_ENTITY',
#        'SECONDARY_ENTITY_BUSINESS_NAME', 'WORKSITE_ADDRESS1',
#        'WORKSITE_ADDRESS2', 'WORKSITE_CITY', 'WORKSITE_COUNTY',
#        'WORKSITE_STATE', 'WORKSITE_POSTAL_CODE', 'WAGE_RATE_OF_PAY_FROM',
#        'WAGE_RATE_OF_PAY_TO', 'WAGE_UNIT_OF_PAY', 'PREVAILING_WAGE',
#        'PW_UNIT_OF_PAY', 'PW_TRACKING_NUMBER', 'PW_WAGE_LEVEL', 'PW_OES_YEAR',
#        'PW_OTHER_SOURCE', 'PW_OTHER_YEAR', 'PW_SURVEY_PUBLISHER',
#        'PW_SURVEY_NAME', 'TOTAL_WORKSITE_LOCATIONS', 'AGREE_TO_LC_STATEMENT',
#        'H-1B_DEPENDENT', 'WILLFUL_VIOLATOR', 'SUPPORT_H1B', 'STATUTORY_BASIS',
#        'APPENDIX_A_ATTACHED', 'PUBLIC_DISCLOSURE', 'PREPARER_LAST_NAME',
#        'PREPARER_FIRST_NAME', 'PREPARER_MIDDLE_INITIAL',
#        'PREPARER_BUSINESS_NAME', 'PREPARER_EMAIL', 'EMPLOYER_POC_ADDRESS_1',
#        'EMPLOYER_POC_ADDRESS_2', 'H1B_DEPENDENT', 'H_1B_DEPENDENT'],
#       dtype='object')
